# %% [markdown]
# <a href="https://colab.research.google.com/github/1900690/image-editing/blob/main/%E8%83%8C%E6%99%AF%E3%81%A8%E5%90%88%E6%88%90%EF%BC%88%E5%9B%9E%E8%BB%A2%E3%82%84%E3%83%A9%E3%83%B3%E3%83%80%E3%83%A0%E7%A7%BB%E5%8B%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title 前景画像（PNG）を取得
import shutil
import os

file_name ="original.zip"

if os.path.exists('/content/foward'):
    shutil.rmtree("/content/foward")

#データを解凍
shutil.unpack_archive('/content/'+file_name, '/content/')
os.rename('/content/'+os.path.splitext(file_name)[0]+'/', '/content/foward/')
#zipを消す
os.remove('/content/'+file_name)

# %%
#@title 背景画像（JPGorPNG）を取得
import shutil
import os

file_name ="OKcls_back.zip"

if os.path.exists('/content/back'):
    shutil.rmtree("/content/back")

#データを解凍
shutil.unpack_archive('/content/'+file_name, '/content/')
if os.path.exists('/content/'+os.path.splitext(file_name)[0]+'/'):
  os.rename('/content/'+os.path.splitext(file_name)[0]+'/', '/content/back/')
else:
  os.rename('/content/original', '/content/back/')
#zipを消す
os.remove('/content/'+file_name)

# %%
shutil.rmtree("/content/.ipynb_checkpoints")

# %%
#@title foward画像がjpgならpngに修正
from PIL import Image
import os
import numpy as np


def convert_jpg_to_png(input_folder, output_folder):
    # 1. 入力フォルダ内のJPEG画像をリストアップ
    jpg_files = [f for f in os.listdir(input_folder) if f.endswith('.jpg')]

    # 2. 出力フォルダが存在しなければ作成
    os.makedirs(output_folder, exist_ok=True)

    # 3. 各JPEG画像をPNGに変換
    for jpg_file in jpg_files:
        jpg_path = os.path.join(input_folder, jpg_file)
        # PNGの出力パスを生成
        png_path = os.path.join(output_folder, os.path.splitext(jpg_file)[0] + '.png')

        # 画像の変換
        img_array = np.array(Image.open(jpg_path).convert('RGBA'))
        for row in img_array:
          for pixel in row:
              if pixel[0] <= 70 and pixel[1] <= 70 and pixel[2] <= 70 :
                  np.put(pixel,3,0)
        #img = Image.fromarray(img_array)
        #白黒反転
        img = Image.fromarray(img_array)
        img.save(png_path, 'PNG')

if __name__ == "__main__":
    input_folder = "/content/foward"  # JPEG画像があるフォルダ
    output_folder = "/content/foward_copy"  # PNG画像を保存するフォルダ

    convert_jpg_to_png(input_folder, output_folder)

# %%
#@title 関数定義
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

def rotate(img, angle, scale):
    """
    画像を回転（反転）させる
    [in]  img:   回転させる画像
    [in]  angle: 回転させる角度
    [in]  scale: 拡大率
    [out] 回転させた画像
    """

    size = img.shape[:2]
    mat = cv2.getRotationMatrix2D((size[0] // 2, size[1] // 2), angle, scale)
    return cv2.warpAffine(img, mat, size, flags=cv2.INTER_CUBIC)


def rotateR(img, level=[-10, 10], scale=1.5):
    """
    ランダムに画像を回転させる
    [in]  img:   回転させる画像
    [in]  level: 回転させる角度の範囲
    [out] 回転させた画像
    [out] 回転させた角度
    """
    angle = np.random.randint(level[0], level[1])
    return rotate(img, angle, scale), angle

def paste(fg, bg, mask_flg=True, random_flg=True):
    """
    背景に前景を重ね合せる
    [in]  fg:         重ね合せる背景
    [in]  bg:         重ね合せる前景
    [in]  mask_flg:   マスク処理を大きめにするフラグ
    [in]  random_flg: 前景をランダムに配置するフラグ
    [out] 重ね合せた画像
    """

    # Load two images
    img1 = bg.copy()
    if random_flg:# ランダム回転
        img2, _ = rotateR(fg, [-90, 90], 1.0)
    else:
        img2 = fg.copy()

    # I want to put logo on top-left corner, So I create a ROI
    w1, h1 = img1.shape[:2]
    w2, h2 = img2.shape[:2]
    if random_flg:# ランダム移動
        x = np.random.randint(0, w1 - w2 + 1)
        y = np.random.randint(0, w1 - w2 + 1)
    else:
        x = 0
        y = 0

    # Ensure the ROI dimensions are within the background image
    x = max(0, min(x, w1 - w2))
    y = max(0, min(y, h1 - h2))


    roi = img1[x:x + w2, y:y + h2]

    # Now create a mask of logo and create its inverse mask also
    mask = img2[:, :, 3]
    ret, mask_inv = cv2.threshold(
        cv2.bitwise_not(mask),
        200, 255, cv2.THRESH_BINARY
    )

    if mask_flg:# 縁を膨張・収縮で作成（膨張大きめ）
        kernel1 = np.ones((5, 5), np.uint8)
        kernel2 = np.ones((3, 3), np.uint8)
        mask_inv = cv2.dilate(mask_inv, kernel1, iterations=1)
        mask_inv = cv2.erode(mask_inv, kernel2, iterations=1)

    # Now black-out the area of logo in ROI
    img1_bg = cv2.bitwise_and(roi, roi, mask=mask_inv)

    # Take only region of logo from logo image.
    img2_fg = cv2.bitwise_and(img2, img2, mask=mask)

    # Resize img2_fg to match img1_bg if necessary
    if img1_bg.shape != img2_fg.shape:
        img2_fg = cv2.resize(img2_fg, (img1_bg.shape[1], img1_bg.shape[0]))

    # Ensure both images have the same number of channels
    if img1_bg.shape[2] != img2_fg.shape[2]:
        # Convert img2_fg to have the same number of channels as img1_bg
        img2_fg = cv2.cvtColor(img2_fg, cv2.COLOR_BGRA2BGR)  # Assuming img2_fg has 4 channels (BGRA)


    # Put logo in ROI and modify the main image
    dst = cv2.add(img1_bg, img2_fg)
    img1[x:x + w2, y:y + h2] = dst
    return img1

# %%
#@title 〇ランダムなペアを選出し、ランダムな位置、角度に合成
import glob
import os
import random
import numpy as np

if not os.path.exists('/content/foward_copy/'):
    shutil.copytree('/content/foward/', '/content/foward_copy/')


#file_list_fimg = sorted(glob.glob('/content/foward_copy/*.png'))
file_list_fimg = sorted(glob.glob('/content/foward/*.jpg'))
file_list_bimg = sorted(glob.glob('/content/back/*.jpg'))


if os.path.exists('/content/output'):
    shutil.rmtree("/content/output")
if not os.path.exists('/content/output'):
    os.makedirs('/content/output')

count=100#画像の枚数

for i in list(range(count)):
  fimg=random.choice(file_list_fimg)
  foward_image=cv2.imread(fimg, -1)

  if not os.path.exists('/content/back'):
    #黒背景に重ねる場合
    back_image=np.zeros((640,640,foward_image.shape[2]),np.uint8)
  else:
    bimg=random.choice(file_list_bimg)
    back_image=cv2.imread(bimg, -1)

  img = paste(
      foward_image,# 前景
      back_image,# 背景
      False,#縁膨張フラグ、
      True,#ランダム回転・移動フラグ
  )
  if not os.path.exists('/content/back'):
    cv2.imwrite('/content/output/black_'+os.path.splitext(os.path.basename(fimg))[0]+str(i).zfill(3)+'.jpg', img)
  else:
    cv2.imwrite('/content/output/'+os.path.splitext(os.path.basename(bimg))[0]+'_'+os.path.splitext(os.path.basename(fimg))[0]+str(i).zfill(3)+'.jpg', img)

cv2_imshow(img)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-5-247740f63657> in <cell line: 0>()
#      32     back_image=cv2.imread(bimg, -1)
#      33
# ---> 34   img = paste(
#      35       foward_image,# 前景
#      36       back_image,# 背景
#
# <ipython-input-3-a8bf64c22565> in paste(fg, bg, mask_flg, random_flg)
#      65
#      66     # Now create a mask of logo and create its inverse mask also
# ---> 67     mask = img2[:, :, 3]
#      68     ret, mask_inv = cv2.threshold(
#      69         cv2.bitwise_not(mask),
#
# IndexError: index 3 is out of bounds for axis 2 with size 3

# %%
#@markdown 作ったファイルをダウンロード
import shutil
import os
from google.colab import files

shutil.make_archive('/content/NGtest', 'zip', '/content/output')
# Out:
# '/content/NGtest.zip'

# %% [markdown]
# #〇指定の位置に合成

# %%
#@title 同じサイズの画像をPNG前JPG後ろで合成
import glob
import os
import random
import numpy as np


file_list_fimg = sorted(glob.glob('/content/foward_copy/*.png'))
file_list_bimg = sorted(glob.glob('/content/back/*.jpg'))


if os.path.exists('/content/output'):
    shutil.rmtree("/content/output")
if not os.path.exists('/content/output'):
    os.makedirs('/content/output')

for i in range(len(file_list_fimg)):
  foward_image=cv2.imread(file_list_fimg[i], -1)
  back_image=cv2.imread(file_list_bimg[i], -1)

  img = paste(
      foward_image,# 前景
      back_image,# 背景
      False,#縁膨張フラグ、
      False,#ランダム回転・移動フラグ
  )
  cv2.imwrite('/content/output/'+os.path.splitext(os.path.basename(file_list_fimg[i]))[0]+'.jpg', img)

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=275x251>

# %%
#@title はめ込む背景を取得　※zip->ファイル->original,csvファイルの構造にすること
import shutil
import os

file_name ="syakuyaku500_20250206112556.zip"

if os.path.exists('/content/fit_in_back_img'):
    shutil.rmtree("/content/fit_in_back_img")

#データを解凍
shutil.unpack_archive('/content/'+file_name, '/content/')
if os.path.exists('/content/'+os.path.splitext(file_name)[0]+'/'):
  os.rename('/content/'+os.path.splitext(file_name)[0]+'/', '/content/fit_in_back_img/')
else:
  os.rename('/content/original', '/content/fit_in_back_img/')
#zipを消す
os.remove('/content/'+file_name)

# %%
#@title csvの位置に従ってはめ込み
import cv2
from google.colab.patches import cv2_imshow
import glob
import os
import pandas as pd
import re

if os.path.exists('/content/back_reaf_img/'):
    shutil.rmtree("/content/back_reaf_img/")
if not os.path.exists('/content/back_reaf_img'):
    os.makedirs('/content/back_reaf_img')

df = pd.read_csv('/content/fit_in_back_img/csv/annotations.csv', usecols=['Name', 'x1', 'y1', 'x2', 'y2'])

img_name = sorted(glob.glob('/content/output/*.jpg'))

for imgname in img_name:
  list_look_up = os.path.basename(imgname)
  fore_img = cv2.imread('/content/output/'+list_look_up)

  if len(list_look_up) >12:
    filtered_df = df[df['Name'].str.contains(re.escape(list_look_up[:7]))]
    back_img_filename = list_look_up[:7] + '.jpg'
    back_img = cv2.imread('/content/fit_in_back_img/original/'+ back_img_filename)
  else:
    filtered_df = df[df['Name'].str.contains(re.escape(list_look_up[:6]))]
    back_img_filename = list_look_up[:6] + '.jpg'
    back_img = cv2.imread('/content/fit_in_back_img/original/'+ back_img_filename)

  #back_img = cv2.imread('/content/fit_in_back_img/original/'+list_look_up[:5]+'.jpg')

  dx=int(filtered_df['x1'])
  dy=int(filtered_df['y1'])
  h, w = fore_img.shape[:2]
  back_img[dy:dy+h, dx:dx+w] = fore_img
  if len(list_look_up) >12:
    cv2.imwrite('/content/back_reaf_img/'+list_look_up[:7]+'.jpg', back_img)
  else:
    cv2.imwrite('/content/back_reaf_img/'+list_look_up[:6]+'.jpg', back_img)

cv2_imshow(back_img)
# Out:
# <ipython-input-7-3f2f9a613126>:33: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   dx=int(filtered_df['x1'])
# <ipython-input-7-3f2f9a613126>:34: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   dy=int(filtered_df['y1'])
# <PIL.Image.Image image mode=RGB size=640x480>

# %%
#@markdown 作ったファイルをダウンロード
import shutil
import os
from google.colab import files

shutil.make_archive('/content/back_reaf_img', 'zip', '/content/back_reaf_img')
# Out:
# '/content/back_reaf_img.zip'

# %% [markdown]
# #〇回転し、大きさを整える

# %%
#@title 画像を取得
import shutil
import os

file_name ="syakuyaku-reaf-only_20250212003459.zip"

if os.path.exists('/content/foward'):
    shutil.rmtree("/content/foward")

#データを解凍
shutil.unpack_archive('/content/'+file_name, '/content/')
#os.rename('/content/'+os.path.splitext(file_name)[0]+'/', '/content/foward/')
os.rename('/content/original/', '/content/foward/')
#zipを消す
os.remove('/content/'+file_name)

# %%
#@title 関数定義
import cv2
from IPython.display import Image, display

def scale_box(img, width, height):
    """指定した大きさに収まるように、アスペクト比を固定して、リサイズする。"""
    h, w = img.shape[:2]
    aspect = w / h
    if width / height >= aspect:
        nh = height
        nw = round(nh * aspect)
    else:
        nw = width
        nh = round(nw / aspect)

    dst = cv2.resize(img, dsize=(nw, nh))

    return dst

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
import glob


if os.path.exists('/content/rotate/'):
    shutil.rmtree("/content/rotate/")
if not os.path.exists('/content/rotate'):
    os.makedirs('/content/rotate')

img_name = sorted(glob.glob('/content/foward/*.jpg'))
#同じ画像を何回増やすか
number=61

for imgname in img_name:
  for i in range(number):
    list_look_up = os.path.basename(imgname)
    img = cv2.imread('/content/foward/'+list_look_up)
    h, w = img.shape[:2]
    angle = np.random.randint(0,360)
    a = np.radians(angle)
    w_rot = int(np.round(w*abs(np.cos(a)) + h*abs(np.sin(a))))
    h_rot = int(np.round(w*abs(np.sin(a)) + h*abs(np.cos(a))))

    M = cv2.getRotationMatrix2D((w/2,h/2), angle, 1)
    M[0][2] += -w/2 + w_rot/2
    M[1][2] += -h/2 + h_rot/2

    img_rot  = cv2.warpAffine(img, M, (w_rot,h_rot))
    dst = scale_box(img_rot, 640, 640)
    cv2.imwrite('/content/rotate/'+list_look_up[:-4]+"_"+str(angle).zfill(3)+'.jpg',dst)

print(len(sorted(glob.glob('/content/rotate/*.jpg'))))
cv2_imshow(dst)
# Out:
# 51
# <PIL.Image.Image image mode=RGB size=498x640>

# %%
#@markdown 作ったファイルをダウンロード
import shutil
import os
from google.colab import files

shutil.make_archive('/content/NGtestrotate', 'zip', '/content/rotate')
# Out:
# '/content/NGtestrotate.zip'
